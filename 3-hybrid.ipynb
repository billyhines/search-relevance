# %%
import ast
import datetime
import json
import os
import time

from elasticsearch import Elasticsearch
import numpy as np
import pandas as pd
import pytrec_eval
from tqdm import tqdm

from query_functions import query_elasticsearch_hybrid

current_timestamp = datetime.datetime.now()

# %%
# Connect to local elastic

es = Elasticsearch('http://localhost:9200')
es.ping()
# Out:
# True

# %% [markdown]
# # Load Data

# %%
def convert_to_dict(string):
    try:
        return ast.literal_eval(string)
    except (SyntaxError, ValueError):
        return None  # Handle cases where the string is not a valid dictionary representation

# %%
def dict_to_string(my_dict):
  result_str = ""
  for key, value in my_dict.items():
    result_str += str(key) + ' ' + str(value) + ' '
  return result_str

# %%
# Products

filename = "processed_data/df_prods.csv"

if os.path.isfile(filename):
    df_prods = pd.read_csv(filename)
    df_prods['product_attributes'] = df_prods['product_attributes'].apply(convert_to_dict)

else:
    print('Cannot locate file')

df_prods.head()
# Out:
#    product_uid                                      product_title  \
# 0       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 2       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 3       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 4       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
#
#                                  product_description  \
# 0  Not only do angles make joints stronger, they ...
# 1  BEHR Premium Textured DECKOVER is an innovativ...
# 2  Update your bathroom with the Delta Vero Singl...
# 3  Achieving delicious results is almost effortle...
# 4  The Quantum Adjustable 2-Light LED Black Emerg...
#
#                                   product_attributes
# 0  {'Bullet01': 'Versatile connector for various ...
# 1  {'Application Method': 'Brush,Roller,Spray', '...
# 2  {'Bath Faucet Type': 'Combo Tub and Shower', '...
# 3  {'Appliance Type': 'Over the Range Microwave',...
# 4  {'Battery Power Type': 'Ni-Cad', 'Battery Size...

# %%
df_prods['product_attributes_string'] = [dict_to_string(x) if x is not None else x for x in df_prods['product_attributes']]
df_prods['product_text_string'] = df_prods['product_title'].fillna('') + ' ' + df_prods['product_description'].fillna('') + ' ' + df_prods['product_attributes_string'].fillna('')

# %%
# Query

filename = "processed_data/df_queries.csv"

if os.path.isfile(filename):
    df_queries = pd.read_csv(filename)
    
else:
    print('Cannot locate file')

df_queries.head()
# Out:
#           search_term                                           query_id  \
# 0       angle bracket  6e0a07626e48aee6f7ce9ec6cd753426d6acafded1598f...
# 1           l bracket  5863e75dfdc9ae5db3f6b4dbddf129d5568e085bf57711...
# 2           deck over  406b3569b2db043604fdb42a67f4ec49964a5ff07cddf0...
# 3    rain shower head  49b2dc56a0e1945c435c1579c07df519878619e3e8d59d...
# 4  shower only faucet  7620551bacb6cdddca5f33ec0943cea7971095a1e9be06...
#
#    has_relevant_results
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
# Relevance

filename = "processed_data/df_relevance.csv"

if os.path.isfile(filename):
    df_relevance = pd.read_csv(filename)
    
else:
    print('Cannot locate file')

df_relevance.head()
# Out:
#                                             query_id  product_uid  relevance
# 0  6e0a07626e48aee6f7ce9ec6cd753426d6acafded1598f...       100001       3.00
# 1  5863e75dfdc9ae5db3f6b4dbddf129d5568e085bf57711...       100001       2.50
# 2  406b3569b2db043604fdb42a67f4ec49964a5ff07cddf0...       100002       3.00
# 3  49b2dc56a0e1945c435c1579c07df519878619e3e8d59d...       100005       2.33
# 4  7620551bacb6cdddca5f33ec0943cea7971095a1e9be06...       100005       2.67

# %% [markdown]
# # Embeddings

# %%
# Embeddings were run on Kaggle for GPU

query_embeddings = np.load('processed_data/query_embeddings.npy')

# %%
df_queries['query_embedding'] = [embedding.tolist() for embedding in query_embeddings]
df_queries.head()
# Out:
#           search_term                                           query_id  \
# 0       angle bracket  6e0a07626e48aee6f7ce9ec6cd753426d6acafded1598f...
# 1           l bracket  5863e75dfdc9ae5db3f6b4dbddf129d5568e085bf57711...
# 2           deck over  406b3569b2db043604fdb42a67f4ec49964a5ff07cddf0...
# 3    rain shower head  49b2dc56a0e1945c435c1579c07df519878619e3e8d59d...
# 4  shower only faucet  7620551bacb6cdddca5f33ec0943cea7971095a1e9be06...
#
#    has_relevant_results                                    query_embedding
# 0                     1  [-0.058361075818538666, 0.026495283469557762, ...
# 1                     1  [-0.027898991480469704, -0.024725843220949173,...
# 2                     1  [-0.07859756052494049, -0.00036610415554605424...
# 3                     1  [-0.020222697407007217, 0.06791018694639206, 0...
# 4                     1  [-0.003950382117182016, 0.012035505846142769, ...

# %% [markdown]
# # Hybrid Queries

# %%
index_name = 'products-embeddings'

# %% [markdown]
# ## Sample Query

# %%
# A sample query

search_query_id = df_queries['query_id'][0]
search_vector = df_queries['query_embedding'][0]
search_text = df_queries['search_term'][0]

results = query_elasticsearch_hybrid(es, index_name, search_text=search_text, search_vector=search_vector, num_results=10)

hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append(h['query_scores'][0]['query_id'])
        relevances.append(h['query_scores'][0]['relevance'])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head()
# Out:
#                 _index                   _id     _score  \
# 0  products-embeddings  VEg05Y8BqeArwfGV1Foe  40.223774
# 1  products-embeddings  gkg95Y8BqeArwfGVwOtd  34.112080
# 2  products-embeddings  _Eg95Y8BqeArwfGVMeH_  34.110950
# 3  products-embeddings  6UlG5Y8BqeArwfGVwXXR  33.917010
# 4  products-embeddings  C0g15Y8BqeArwfGVuWlK  31.861212
#
#                                              _source  product_uid  \
# 0  {'product_uid': 198519, 'product_title': 'Vera...       198519
# 1  {'product_uid': 174846, 'product_title': 'Marq...       174846
# 2  {'product_uid': 170398, 'product_title': 'Marq...       170398
# 3  {'product_uid': 223811, 'product_title': 'Marq...       223811
# 4  {'product_uid': 102005, 'product_title': 'Supe...       102005
#
#                                        product_title  \
# 0  Veranda White Vinyl Traditional Left/Right Ang...
# 1  Marquee Railing Black Left Multi-Angle Bracket...
# 2  Marquee Railing Black Right Multi-Angle Bracke...
# 3  Marquee Railing White Left Multi-Angle Bracket...
# 4  Superstrut 90Ë 4-Hole Angle Bracket - Silver ...
#
#                                  product_description  \
# 0  The Traditional Vinyl White Left/Right Angle B...
# 1  Designed with a beautiful hammered-metal look,...
# 2  Designed with a beautiful hammered-metal look,...
# 3  Designed with a beautiful hammered-metal look,...
# 4  The Superstrut 90-Degree 4-Hole Channel Bracke...
#
#                                    product_attribute  \
# 0  [{'name': 'Accessory type', 'value': 'Left/Rig...
# 1  [{'name': 'Accessory type', 'value': 'Bracket'...
# 2  [{'name': 'Accessory type', 'value': 'Bracket'...
# 3  [{'name': 'Accessory type', 'value': 'Bracket'...
# 4  [{'name': 'Bullet01', 'value': 'Use to support...
#
#                                             query_id  relevance
# 0  45476ecfe43c98557ae68d2eec00a37d8f21c0fef3d913...       2.00
# 1                                               None        NaN
# 2                                               None        NaN
# 3                                               None        NaN
# 4  b39f9b993b97bb3eb11c9dc73220691215ab99971b52b7...       2.67

# %% [markdown]
# ## Run the vector queries

# %%
# Filter down to queries that have results

relevant_queries = df_queries[df_queries['has_relevant_results']==1]

# %%
boosts = {"title_boost": 8,
          "description_boost": 2,
          "attributes_boost": 1,
          "product_text_string_vector_boost": 1}

# %%
# Create query result dictionaries

filename = "query_runs/run_hybrid.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_h = json.load(file)
else:
    run_h = {}

    start_time = time.time()

    for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
        search_vector = row['query_embedding']
        search_query_id = row['query_id']
        search_text = row['search_term']

        results = query_elasticsearch_hybrid(es, index_name, search_text=search_text,
                                                search_vector=search_vector, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run_h[search_query_id] = query_doc_dict

    end_time = time.time() 

    with open(filename, "w") as file:
        json.dump(run_h, file)
# Out:
# 100%|██████████| 11795/11795 [11:02<00:00, 17.80it/s]

# %% [markdown]
# ## Evaluate Results

# %%
# Load ground truth
filename = "query_runs/qrel.json"

with open(filename, "r") as file:
    qrel = json.load(file)

# %%
# Place to store results and initialize an evaluator

ranking_results = []
measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

# %%
# Evaluate hybrid queries

results_df = pd.DataFrame(evaluator.evaluate(run_h))
results_dict = {}
for measure in measures:
    results_dict['mean '+measure] = results_df.loc[measure].mean()
results_df = pd.DataFrame(results_dict, index=[0])

results_df['run_name'] = 'hybrid'
results_df['run_time'] = end_time - start_time
results_df['run_timestamp'] = current_timestamp

ranking_results.append(results_df)

# %%
# Put the results into a dataframe, add to previous results

ranking_results = pd.concat(ranking_results)

all_results = pd.read_csv('query_runs/query_results.csv')
all_results = pd.concat([all_results, ranking_results])
all_results
# Out:
#    mean ndcg_cut_10  mean map_cut_10  mean recip_rank  \
# 0          0.170037         0.112637         0.261150
# 1          0.217595         0.149411         0.317710
# 2          0.236762         0.159441         0.330878
# 3          0.155515         0.096555         0.241066
# 4          0.167586         0.106110         0.254867
# 0          0.238384         0.162870         0.324941
#
#                         run_name    run_time               run_timestamp
# 0                     textsearch  178.504840  2024-05-06 20:30:09.220148
# 1             textsearch_boosted  207.407446  2024-05-06 20:30:09.220148
# 2                   vectorsearch  509.612543  2024-06-23 12:50:09.220148
# 3        vectorsearch_multifield  622.987846  2024-06-23 12:50:09.220148
# 4  vectorsearch_multifield_tuned  662.439398  2024-06-23 12:50:09.220148
# 0                         hybrid  662.608457  2024-06-23 13:25:22.725108

# %% [markdown]
# # Tune Vector Boosts

# %%
boost_list = []

for b in [10,50,100,200]:
    boost_list.append({"title_boost": 8,
                        "description_boost": 2,
                        "attributes_boost": 1,
                        "vector_boost": b})

# %%
# Run hybrid queries with boosts

measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

for boosts in tqdm(boost_list):

    run = {}

    for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
        search_vector = row['query_embedding']
        search_query_id = row['query_id']
        search_text = row['search_term']

        results = query_elasticsearch_hybrid(es, index_name, search_text, search_vector, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run[search_query_id] = query_doc_dict

    results_df = pd.DataFrame(evaluator.evaluate(run))
    results_dict = {}
    for measure in measures:
        results_dict['mean '+measure] = results_df.loc[measure].mean()
    results_df = pd.DataFrame(results_dict, index=[0])

    boosts['mean map_cut_10'] = results_df['mean map_cut_10'].values[0]
    boosts['mean ndcg_cut_10'] = results_df['mean ndcg_cut_10'].values[0]
    boosts['mean recip_rank'] = results_df['mean recip_rank'].values[0]

# %%
pd.DataFrame(boost_list).sort_values('mean ndcg_cut_10')

# %%
for b in [25,75]:
    boost_list.append({"title_boost": 8,
                        "description_boost": 2,
                        "attributes_boost": 1,
                        "vector_boost": b})

# %%
# Run hybrid queries with boosts

measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

for boosts in tqdm(boost_list[-2:]):

    run = {}

    for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
        search_vector = row['query_embedding']
        search_query_id = row['query_id']
        search_text = row['search_term']

        results = query_elasticsearch_hybrid(es, index_name, search_text, search_vector, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run[search_query_id] = query_doc_dict

    results_df = pd.DataFrame(evaluator.evaluate(run))
    results_dict = {}
    for measure in measures:
        results_dict['mean '+measure] = results_df.loc[measure].mean()
    results_df = pd.DataFrame(results_dict, index=[0])

    boosts['mean map_cut_10'] = results_df['mean map_cut_10'].values[0]
    boosts['mean ndcg_cut_10'] = results_df['mean ndcg_cut_10'].values[0]
    boosts['mean recip_rank'] = results_df['mean recip_rank'].values[0]

# %%
pd.DataFrame(boost_list).sort_values('vector_boost')

# %%
for b in [40,60]:
    boost_list.append({"title_boost": 8,
                        "description_boost": 2,
                        "attributes_boost": 1,
                        "vector_boost": b})

# %%
# Run hybrid queries with boosts

measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

for boosts in tqdm(boost_list[-2:]):

    run = {}

    for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
        search_vector = row['query_embedding']
        search_query_id = row['query_id']
        search_text = row['search_term']

        results = query_elasticsearch_hybrid(es, index_name, search_text, search_vector, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run[search_query_id] = query_doc_dict

    results_df = pd.DataFrame(evaluator.evaluate(run))
    results_dict = {}
    for measure in measures:
        results_dict['mean '+measure] = results_df.loc[measure].mean()
    results_df = pd.DataFrame(results_dict, index=[0])

    boosts['mean map_cut_10'] = results_df['mean map_cut_10'].values[0]
    boosts['mean ndcg_cut_10'] = results_df['mean ndcg_cut_10'].values[0]
    boosts['mean recip_rank'] = results_df['mean recip_rank'].values[0]

# %%
pd.DataFrame(boost_list).sort_values('mean ndcg_cut_10')

# %%
boosts = {"title_boost": 8,
          "description_boost": 2,
          "attributes_boost": 1,
          "product_text_string_vector_boost": 50}

# %%
# Create query result dictionaries

filename = "query_runs/run_hybrid_boosted.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_hb = json.load(file)
else:
    run_hb = {}

    start_time = time.time()

    for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
        search_vector = row['query_embedding']
        search_query_id = row['query_id']
        search_text = row['search_term']

        results = query_elasticsearch_hybrid(es, index_name, search_text=search_text,
                                                search_vector=search_vector, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run_hb[search_query_id] = query_doc_dict

    end_time = time.time() 

    with open(filename, "w") as file:
        json.dump(run_hb, file)
# Out:
# 100%|██████████| 11795/11795 [11:56<00:00, 16.47it/s]

# %% [markdown]
# ## Evaluate Results

# %%
# Place to store results and initialize an evaluator

ranking_results = []
measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

# %%
# Evaluate hybrid queries

results_df = pd.DataFrame(evaluator.evaluate(run_hb))
results_dict = {}
for measure in measures:
    results_dict['mean '+measure] = results_df.loc[measure].mean()
results_df = pd.DataFrame(results_dict, index=[0])

results_df['run_name'] = 'hybrid_boosted'
results_df['run_time'] = end_time - start_time
results_df['run_timestamp'] = current_timestamp

ranking_results.append(results_df)

# %%
# Put the results into a dataframe, add to previous results

ranking_results = pd.concat(ranking_results)
all_results = pd.concat([all_results, ranking_results])
all_results
# Out:
#    mean ndcg_cut_10  mean map_cut_10  mean recip_rank  \
# 0          0.170037         0.112637         0.261150
# 1          0.217595         0.149411         0.317710
# 2          0.236762         0.159441         0.330878
# 3          0.155515         0.096555         0.241066
# 4          0.167586         0.106110         0.254867
# 0          0.238384         0.162870         0.324941
# 0          0.251350         0.170474         0.342187
#
#                         run_name    run_time               run_timestamp
# 0                     textsearch  178.504840  2024-05-06 20:30:09.220148
# 1             textsearch_boosted  207.407446  2024-05-06 20:30:09.220148
# 2                   vectorsearch  509.612543  2024-06-23 12:50:09.220148
# 3        vectorsearch_multifield  622.987846  2024-06-23 12:50:09.220148
# 4  vectorsearch_multifield_tuned  662.439398  2024-06-23 12:50:09.220148
# 0                         hybrid  662.608457  2024-06-23 13:25:22.725108
# 0                 hybrid_boosted  716.318870  2024-06-23 13:25:22.725108

# %%
all_results.to_csv('query_runs/query_results.csv', index=False)

# %% [markdown]
# # Queries with Results

# %%
text_searches_without_hits = 0
hybrid_searches_without_hits = 0

for index,row in tqdm(relevant_queries.iterrows(), total=len(relevant_queries)):
    search_vector = row['query_embedding']
    search_query_id = row['query_id']
    search_text = row['search_term']

    text_results = query_elasticsearch_hybrid(es, index_name, search_text=search_text,
                                              num_results=10, boost_values=boosts)
    text_hits = pd.DataFrame(text_results['hits']['hits'])

    if len(text_hits)==0:
        text_searches_without_hits+=1

    hybrid_results = query_elasticsearch_hybrid(es, index_name, search_text=search_text,
                                                search_vector=search_vector,
                                                num_results=10, boost_values=boosts)
    hybrid_hits = pd.DataFrame(hybrid_results['hits']['hits'])

    if len(hybrid_hits)==0:
        hybrid_searches_without_hits+=1

# %%
text_searches_without_hits / len(relevant_queries)

# %%
hybrid_searches_without_hits / len(relevant_queries)

# %% [markdown]
# # Sample Queries

# %%
import os

# %%
# Load ground truth
filename = "query_runs/qrel.json"

with open(filename, "r") as file:
    qrel = json.load(file)

# Text
filename = "query_runs/run_boosted.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_t = json.load(file)
        
# Vector
filename = "query_runs/run_vector.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_v = json.load(file)

# Hybrid
filename = "query_runs/run_hybrid_boosted.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_h = json.load(file)

# %%
ranking_results = []
measures = {'ndcg_cut_10'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

# %%
results_df = pd.DataFrame(evaluator.evaluate(run_t))
results_df = results_df.T
results_df.rename(columns={'ndcg_cut_10': 'ndcg_cut_10_text'}, inplace=True)

results_df_2 = pd.DataFrame(evaluator.evaluate(run_v))
results_df_2 = results_df_2.T
results_df_2.rename(columns={'ndcg_cut_10': 'ndcg_cut_10_vector'}, inplace=True)

results_df = results_df.merge(results_df_2, how='left', left_index=True, right_index=True)

results_df_2 = pd.DataFrame(evaluator.evaluate(run_h))
results_df_2 = results_df_2.T
results_df_2.rename(columns={'ndcg_cut_10': 'ndcg_cut_10_hybrid'}, inplace=True)

results_df = results_df.merge(results_df_2, how='left', left_index=True, right_index=True)

results_df['h_minus_v'] = results_df['ndcg_cut_10_hybrid'] - results_df['ndcg_cut_10_vector']
results_df['v_minus_t'] = results_df['ndcg_cut_10_vector'] - results_df['ndcg_cut_10_text']

results_df[(results_df['h_minus_v']>0) & (results_df['v_minus_t']>0) & (results_df['ndcg_cut_10_text']>0)].sort_values('h_minus_v', ascending=False).head(10)
# Out:
#                                                     ndcg_cut_10_text  \
# 40ce92c92b5777f7f83c57b93db3f7e2ce8a5f09676a17c...          0.201515
# b4f4a18e032207b9f91f899f366bdc8715369d8d70348da...          0.500000
# 57657f3064d298a9f70967f5d4b33f247c26f3e13c10304...          0.326386
# 012a4e265162adc17e6680e174116b9f55dd590f8cee25b...          0.149824
# 3b3fea9ac8be367e689cc0e80323275db96d7d9426cf02a...          0.083409
# a9b59ad2657f5b2d9b9f1b8d5b41516475efa5540ff0ab6...          0.237198
# 1629f47ede2d4729a23611ca2110c09e3ff916fcecb06c9...          0.265826
# f025d0011dd596a09a1a3c6ee6f3c227ead362e0a2ec953...          0.192294
# 5620846ec4ac55e556f76c13b0473988ad34edc67444df1...          0.110046
# 18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec61...          0.156607
#
#                                                     ndcg_cut_10_vector  \
# 40ce92c92b5777f7f83c57b93db3f7e2ce8a5f09676a17c...            0.247117
# b4f4a18e032207b9f91f899f366bdc8715369d8d70348da...            0.630930
# 57657f3064d298a9f70967f5d4b33f247c26f3e13c10304...            0.432111
# 012a4e265162adc17e6680e174116b9f55dd590f8cee25b...            0.189057
# 3b3fea9ac8be367e689cc0e80323275db96d7d9426cf02a...            0.215610
# a9b59ad2657f5b2d9b9f1b8d5b41516475efa5540ff0ab6...            0.264068
# 1629f47ede2d4729a23611ca2110c09e3ff916fcecb06c9...            0.468348
# f025d0011dd596a09a1a3c6ee6f3c227ead362e0a2ec953...            0.319394
# 5620846ec4ac55e556f76c13b0473988ad34edc67444df1...            0.136985
# 18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec61...            0.221994
#
#                                                     ndcg_cut_10_hybrid  \
# 40ce92c92b5777f7f83c57b93db3f7e2ce8a5f09676a17c...            0.638788
# b4f4a18e032207b9f91f899f366bdc8715369d8d70348da...            1.000000
# 57657f3064d298a9f70967f5d4b33f247c26f3e13c10304...            0.800767
# 012a4e265162adc17e6680e174116b9f55dd590f8cee25b...            0.544751
# 3b3fea9ac8be367e689cc0e80323275db96d7d9426cf02a...            0.567255
# a9b59ad2657f5b2d9b9f1b8d5b41516475efa5540ff0ab6...            0.613147
# 1629f47ede2d4729a23611ca2110c09e3ff916fcecb06c9...            0.804889
# f025d0011dd596a09a1a3c6ee6f3c227ead362e0a2ec953...            0.638788
# 5620846ec4ac55e556f76c13b0473988ad34edc67444df1...            0.444755
# 18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec61...            0.525914
#
#                                                     h_minus_v  v_minus_t
# 40ce92c92b5777f7f83c57b93db3f7e2ce8a5f09676a17c...   0.391671   0.045602
# b4f4a18e032207b9f91f899f366bdc8715369d8d70348da...   0.369070   0.130930
# 57657f3064d298a9f70967f5d4b33f247c26f3e13c10304...   0.368656   0.105725
# 012a4e265162adc17e6680e174116b9f55dd590f8cee25b...   0.355694   0.039233
# 3b3fea9ac8be367e689cc0e80323275db96d7d9426cf02a...   0.351645   0.132201
# a9b59ad2657f5b2d9b9f1b8d5b41516475efa5540ff0ab6...   0.349079   0.026870
# 1629f47ede2d4729a23611ca2110c09e3ff916fcecb06c9...   0.336541   0.202522
# f025d0011dd596a09a1a3c6ee6f3c227ead362e0a2ec953...   0.319394   0.127100
# 5620846ec4ac55e556f76c13b0473988ad34edc67444df1...   0.307770   0.026939
# 18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec61...   0.303920   0.065387

# %%
sample_query_id = '18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec612c19636a7e1c276e0'

# A sample text query

search_text = df_queries[df_queries['query_id']==sample_query_id]['search_term'].values[0]
search_vector = df_queries[df_queries['query_id']==sample_query_id]['query_embedding'].values[0]

print(search_text)
# Out:
# house paint dark brown

# %%
t_boosts = {"title_boost": 8,
          "description_boost": 2,
          "attributes_boost": 1}

h_boosts = {"title_boost": 8,
          "description_boost": 2,
          "attributes_boost": 1,
          "product_text_string_vector_boost": 50}

# %% [markdown]
# ### Text Search

# %%
results = query_elasticsearch_hybrid(es, 'products-embeddings',
                                     search_text=search_text, boost_values=t_boosts)

hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append([x['query_id'] for x in h['query_scores']])
        relevances.append([x['relevance'] for x in h['query_scores'] if x['query_id']==sample_query_id])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(10)
# Out:
#                 _index                   _id      _score  \
# 0  products-embeddings  bUg05Y8BqeArwfGV1VqC  125.695680
# 1  products-embeddings  L0gw5Y8BqeArwfGVjhhu  121.832520
# 2  products-embeddings  _Eg75Y8BqeArwfGVMr3B  117.351234
# 3  products-embeddings  hEgx5Y8BqeArwfGVeyaf  115.946480
# 4  products-embeddings  Tkg15Y8BqeArwfGVHl_o  115.637310
# 5  products-embeddings  V0k_5Y8BqeArwfGVXQao  115.141690
# 6  products-embeddings  ZElG5Y8BqeArwfGVWW9B  114.149506
# 7  products-embeddings  ikcr5Y8BqeArwfGVd8i_  113.164710
# 8  products-embeddings  bUlC5Y8BqeArwfGVszM-  112.707110
# 9  products-embeddings  TEg55Y8BqeArwfGV_ql7  112.703570
#
#                                              _source  product_uid  \
# 0  {'product_uid': 198579, 'product_title': 'Rust...       198579
# 1  {'product_uid': 160692, 'product_title': 'Marv...       160692
# 2  {'product_uid': 152689, 'product_title': 'Home...       152689
# 3  {'product_uid': 168302, 'product_title': 'Euro...       168302
# 4  {'product_uid': 201655, 'product_title': 'Arch...       201655
# 5  {'product_uid': 187177, 'product_title': 'Euro...       187177
# 6  {'product_uid': 222142, 'product_title': 'Leat...       222142
# 7  {'product_uid': 122097, 'product_title': 'Hamp...       122097
# 8  {'product_uid': 206792, 'product_title': 'Vene...       206792
# 9  {'product_uid': 141721, 'product_title': 'Dark...       141721
#
#                                        product_title  \
# 0  Rust-Oleum Stops Rust 12-oz. Protective Enamel...
# 1  Marvy Uchida DecoColor Dark Brown Broad Point ...
# 2         HomeSullivan Dark Brown Upholstered Daybed
# 3  Eurostyle 24x30x0.75 in. Finishing End Panel i...
# 4  Architectural Mailboxes 5 in. Dark Aged Copper...
# 5  Eurostyle 24x80x0.75 in. Replacement End Panel...
# 6          Leather-Look Chaise Lounger in Dark Brown
# 7  Hampton Bay Outdoor Dark Brown Solar LED Walk ...
# 8  Venetian Worldwide Clive Microfiber Recliner i...
# 9       Dark Brown Upholstered Side Chair (Set of 2)
#
#                                  product_description  \
# 0  The Rust-Oleum Stops Rust 12 oz Satin Dark Bro...
# 1  DecoColor bold point oil-based paint markers a...
# 2  Perfect for the multifunctional space, this up...
# 3  Use the Eurostyle 24x30 in. Finishing Panel to...
# 4  The Solid Cast Brass 5 in. Floating House Numb...
# 5  The Eurostyle 24x80 in. Replacement Panel repl...
# 6  Stretch out in comfort on this gently contoure...
# 7  The Hampton Bay Outdoor Solar LED Walk Lights ...
# 8  Enjoy an afternoon nap, the big game or your f...
# 9  The rich cherry finished rubberwood with dark ...
#
#                                    product_attribute  \
# 0  [{'name': 'Application Method', 'value': 'Spra...
# 1                                                 []
# 2                                                 []
# 3  [{'name': 'Bullet01', 'value': 'High quality m...
# 4  [{'name': 'Background', 'value': 'No', 'name_v...
# 5  [{'name': 'Bullet01', 'value': 'High quality v...
# 6                                                 []
# 7  [{'name': 'Adjustable Lamp Head', 'value': 'No...
# 8                                                 []
# 9                                                 []
#
#                                             query_id relevance
# 0  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...     [2.0]
# 1  [ab76b8fd575a57e3ec2581916471cb7ace994a2a1e5f7...        []
# 2                                               None      None
# 3  [5ea5ad8064f9f1dfe2fcfff5fddb3ff8125b4238f9665...        []
# 4  [a8f12e63719abf8826c27fe659612a01cda2eaa8885bc...        []
# 5                                               None      None
# 6                                               None      None
# 7  [17ffef03f62e3eb0a720f0d6011b9f74329899fa1fa24...        []
# 8                                               None      None
# 9                                               None      None

# %% [markdown]
# ### Vector Search

# %%
results = query_elasticsearch_hybrid(es, 'products-embeddings', search_vector=search_vector)
hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append([x['query_id'] for x in h['query_scores']])
        relevances.append([x['relevance'] for x in h['query_scores'] if x['query_id']==sample_query_id])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(10)
# Out:
#                 _index                   _id    _score  \
# 0  products-embeddings  20gw5Y8BqeArwfGVehZQ  0.728150
# 1  products-embeddings  DUgw5Y8BqeArwfGVjBhT  0.726483
# 2  products-embeddings  cUg05Y8BqeArwfGVdFQ0  0.723400
# 3  products-embeddings  rkgz5Y8BqeArwfGVm0a7  0.720089
# 4  products-embeddings  WEcq5Y8BqeArwfGVWLVR  0.719881
# 5  products-embeddings  dkgv5Y8BqeArwfGVwAuC  0.719701
# 6  products-embeddings  ykg95Y8BqeArwfGVhufZ  0.719561
# 7  products-embeddings  6Ugy5Y8BqeArwfGVzznU  0.719055
# 8  products-embeddings  z0g15Y8BqeArwfGVRWFd  0.718674
# 9  products-embeddings  A0lF5Y8BqeArwfGV2mcb  0.718509
#
#                                              _source  product_uid  \
# 0  {'product_uid': 159946, 'product_title': 'Glid...       159946
# 1  {'product_uid': 160596, 'product_title': 'BEHR...       160596
# 2  {'product_uid': 194932, 'product_title': 'Glid...       194932
# 3  {'product_uid': 186643, 'product_title': 'BEHR...       186643
# 4  {'product_uid': 113895, 'product_title': 'BEHR...       113895
# 5  {'product_uid': 153916, 'product_title': 'BEHR...       153916
# 6  {'product_uid': 173124, 'product_title': 'BEHR...       173124
# 7  {'product_uid': 179276, 'product_title': 'Glid...       179276
# 8  {'product_uid': 203177, 'product_title': 'Glid...       203177
# 9  {'product_uid': 219997, 'product_title': 'BEHR...       219997
#
#                                        product_title  \
# 0  Glidden Premium 1-gal. #HDGWN13 Stewart House ...
# 1  BEHR MARQUEE Home Decorators Collection #HDC-C...
# 2  Glidden Premium 5-gal. #HDGWN13 Stewart House ...
# 3  BEHR MARQUEE Home Decorators Collection #HDC-A...
# 4             BEHR MARQUEE #MQ1-43 Piano Brown Paint
# 5  BEHR MARQUEE #S170-7 Dark Cherry Mocha Exterio...
# 6          BEHR Premium Plus #BNC-29 Dark Room Paint
# 7  Glidden Premium 1-gal. #HDGWN13 Stewart House ...
# 8  Glidden Premium 5-gal. #HDGR39D Ranch House Br...
# 9  BEHR MARQUEE #BXC-45 Classic Brown Exterior Paint
#
#                                  product_description  \
# 0  The Glidden Premium 1-gal. Satin Latex Exterio...
# 1  BEHR MARQUEE Flat Exterior is a stain-blocking...
# 2  The Glidden 5-gal. Flat Interior Paint provide...
# 3  BEHR MARQUEE Semi-Gloss Enamel Exterior is a s...
# 4  For the ultimate in durability and beauty on v...
# 5  For a classic, cultivated look on your home's ...
# 6  For tough, all-purpose paint with a touch of s...
# 7  The Glidden Premium 1-gal. Semi-Gloss Latex Ex...
# 8  The Glidden 5-gal. Semi-Gloss Latex Interior P...
# 9  Add dazzling impact and style to your homes ex...
#
#                                    product_attribute  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'name': 'Bullet01', 'value': 'Protection for...
# 4                                                 []
# 5                                                 []
# 6  [{'name': 'Bullet01', 'value': 'Ideal for fami...
# 7                                                 []
# 8                                                 []
# 9  [{'name': 'Bullet01', 'value': 'Protection for...
#
#                                             query_id relevance
# 0  [6e9c28e6c0af4f0383a87f0efc2505252e423cf3fee87...        []
# 1  [3409ac7b187b4862d11b98bca5763b41cae807a86d468...        []
# 2  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...    [2.33]
# 3  [beb53d2cda1cd4d698b0d94a9b8deb85eb48e19e1b36c...        []
# 4  [6e9c28e6c0af4f0383a87f0efc2505252e423cf3fee87...        []
# 5  [3409ac7b187b4862d11b98bca5763b41cae807a86d468...        []
# 6                                               None      None
# 7  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...     [2.0]
# 8  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...    [2.67]
# 9                                               None      None

# %% [markdown]
# ### Hybrid Seach

# %%
results = query_elasticsearch_hybrid(es, index_name, search_text=search_text,
                                        search_vector=search_vector, num_results=10, boost_values=h_boosts)
hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append([x['query_id'] for x in h['query_scores']])
        relevances.append([x['relevance'] for x in h['query_scores'] if x['query_id']==sample_query_id])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(10)
# Out:
#                 _index                   _id     _score  \
# 0  products-embeddings  20gw5Y8BqeArwfGVehZQ  148.02765
# 1  products-embeddings  G0gx5Y8BqeArwfGV2CwN  146.89905
# 2  products-embeddings  6Ugy5Y8BqeArwfGVzznU  143.38411
# 3  products-embeddings  cUg05Y8BqeArwfGVdFQ0  142.18007
# 4  products-embeddings  r0g05Y8BqeArwfGVuVhP  141.48108
# 5  products-embeddings  Z0g05Y8BqeArwfGVFU6l  141.01993
# 6  products-embeddings  z0g15Y8BqeArwfGVRWFd  137.15631
# 7  products-embeddings  wUlA5Y8BqeArwfGVuRm1  135.13614
# 8  products-embeddings  qkgz5Y8BqeArwfGV7UvB  129.95815
# 9  products-embeddings  cUg45Y8BqeArwfGVh5VG  129.46760
#
#                                              _source  product_uid  \
# 0  {'product_uid': 159946, 'product_title': 'Glid...       159946
# 1  {'product_uid': 171355, 'product_title': 'Glid...       171355
# 2  {'product_uid': 179276, 'product_title': 'Glid...       179276
# 3  {'product_uid': 194932, 'product_title': 'Glid...       194932
# 4  {'product_uid': 197507, 'product_title': 'Glid...       197507
# 5  {'product_uid': 191297, 'product_title': 'Glid...       191297
# 6  {'product_uid': 203177, 'product_title': 'Glid...       203177
# 7  {'product_uid': 195767, 'product_title': 'BEHR...       195767
# 8  {'product_uid': 189614, 'product_title': 'Ralp...       189614
# 9  {'product_uid': 130700, 'product_title': 'BEHR...       130700
#
#                                        product_title  \
# 0  Glidden Premium 1-gal. #HDGWN13 Stewart House ...
# 1  Glidden Premium 5-gal. #HDGWN13 Stewart House ...
# 2  Glidden Premium 1-gal. #HDGWN13 Stewart House ...
# 3  Glidden Premium 5-gal. #HDGWN13 Stewart House ...
# 4  Glidden Premium 1-gal. #HDGWN13 Stewart House ...
# 5  Glidden Premium 1-gal. #HDGR39D Ranch House Br...
# 6  Glidden Premium 5-gal. #HDGR39D Ranch House Br...
# 7       BEHR Premium Plus #M140-7 Dark Crimson Paint
# 8  Ralph Lauren #RL1320 Country House Interior Paint
# 9             BEHR MARQUEE #MQ2-51 Pasha Brown Paint
#
#                                  product_description  \
# 0  The Glidden Premium 1-gal. Satin Latex Exterio...
# 1  The Glidden 5-gal. Flat Latex Exterior Paint c...
# 2  The Glidden Premium 1-gal. Semi-Gloss Latex Ex...
# 3  The Glidden 5-gal. Flat Interior Paint provide...
# 4  Add a smooth sheen to indoor surfaces such as ...
# 5  Featuring a stain-resistant, high-coverage lat...
# 6  The Glidden 5-gal. Semi-Gloss Latex Interior P...
# 7  For a paint that's as versatile as it is beaut...
# 8  Ralph Lauren Paint represents a tradition of e...
# 9  Take a new twist on neutrals with BEHR MARQUEE...
#
#                                    product_attribute  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [{'name': 'Bullet01', 'value': 'Ideal for fami...
# 8  [{'name': 'Bullet01', 'value': 'Superior color...
# 9                                                 []
#
#                                             query_id relevance
# 0  [6e9c28e6c0af4f0383a87f0efc2505252e423cf3fee87...        []
# 1  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...    [1.67]
# 2  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...     [2.0]
# 3  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...    [2.33]
# 4  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...     [3.0]
# 5  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...     [2.0]
# 6  [18c245dedc8017569265ec2d7c1a64c57cdd16b7621ec...    [2.67]
# 7                                               None      None
# 8  [ff07e37c6afef6c3ac509ef4e5d65d2fb22c4ee63b08e...        []
# 9                                               None      None
