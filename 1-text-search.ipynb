# %%
import ast
import datetime
import json
import os
import time

from elasticsearch import Elasticsearch
import pandas as pd
import pytrec_eval
from tqdm import tqdm

current_timestamp = datetime.datetime.now()

# %%
# Connect to local elastic

es = Elasticsearch('http://localhost:9200')
es.ping()
# Out:
# True

# %% [markdown]
# # Load Data

# %%
def convert_to_dict(string):
    try:
        return ast.literal_eval(string)
    except (SyntaxError, ValueError):
        return None  # Handle cases where the string is not a valid dictionary representation

# %% [markdown]
# ## Products

# %%
# Products

filename = "processed_data/df_prods.csv"

df_prods = pd.read_csv(filename)
df_prods['product_attributes'] = df_prods['product_attributes'].apply(convert_to_dict)

df_prods.head()
# Out:
#    product_uid                                      product_title  \
# 0       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 2       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 3       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 4       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
#
#                                  product_description  \
# 0  Not only do angles make joints stronger, they ...
# 1  BEHR Premium Textured DECKOVER is an innovativ...
# 2  Update your bathroom with the Delta Vero Singl...
# 3  Achieving delicious results is almost effortle...
# 4  The Quantum Adjustable 2-Light LED Black Emerg...
#
#                                   product_attributes
# 0  {'Bullet01': 'Versatile connector for various ...
# 1  {'Application Method': 'Brush,Roller,Spray', '...
# 2  {'Bath Faucet Type': 'Combo Tub and Shower', '...
# 3  {'Appliance Type': 'Over the Range Microwave',...
# 4  {'Battery Power Type': 'Ni-Cad', 'Battery Size...

# %% [markdown]
# ## Queries

# %%
# Queries

filename = "processed_data/df_queries.csv"

df_queries = pd.read_csv(filename)
df_queries.head()
# Out:
#           search_term                                           query_id  \
# 0       angle bracket  6e0a07626e48aee6f7ce9ec6cd753426d6acafded1598f...
# 1           l bracket  5863e75dfdc9ae5db3f6b4dbddf129d5568e085bf57711...
# 2           deck over  406b3569b2db043604fdb42a67f4ec49964a5ff07cddf0...
# 3    rain shower head  49b2dc56a0e1945c435c1579c07df519878619e3e8d59d...
# 4  shower only faucet  7620551bacb6cdddca5f33ec0943cea7971095a1e9be06...
#
#    has_relevant_results
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %% [markdown]
# ## Query Relevance

# %%
# Join query_ids onto df_train

filename = "processed_data/df_relevance.csv"

df_relevance = pd.read_csv(filename)
df_relevance.head()
# Out:
#                                             query_id  product_uid  relevance
# 0  6e0a07626e48aee6f7ce9ec6cd753426d6acafded1598f...       100001       3.00
# 1  5863e75dfdc9ae5db3f6b4dbddf129d5568e085bf57711...       100001       2.50
# 2  406b3569b2db043604fdb42a67f4ec49964a5ff07cddf0...       100002       3.00
# 3  49b2dc56a0e1945c435c1579c07df519878619e3e8d59d...       100005       2.33
# 4  7620551bacb6cdddca5f33ec0943cea7971095a1e9be06...       100005       2.67

# %% [markdown]
# # Load into index

# %%
# Initialize the index

index_name = 'products'

mapping = {
    "properties": {
        "product_uid": {
            "type": "integer"
        },
        "product_title": {
            "type": "text"
        },
        "product_description": {
            "type": "text"
        },
        "product_attributes": {
            "type": "nested",
            "properties": {
                "name": {
                    "type": "text"
                },
                "value": {
                    "type": "text"
                },
                "name_value": {
                    "type": "text"
                },
            }
        },
        "query_scores": {
            "type": "nested",
            "properties": {
                "query_id": {
                    "type": "text"
                },
                "relevance": {
                    "type": "float"
                },
            }
        }
    }
}

#es.indices.create(index=index_name, mappings=mapping)

# %%
# Create documents for indexing

product_document_list = []

for index, row in tqdm(df_prods.iterrows(), total=len(df_prods)):
    
    query_scores = []
    tmp_query = df_relevance[(df_relevance['product_uid']==row['product_uid'])]
    if len(tmp_query)>0:
        tmp_query = tmp_query.replace(pd.NA, '', regex=True)
        for index_q, row_q in tmp_query.iterrows():
            query_scores.append({'query_id': row_q['query_id'],
                                 'relevance': row_q['relevance']})

    product_attributes = []
    tmp_attr = row['product_attributes']
    if not pd.isnull(tmp_attr):
        for k in tmp_attr.keys():
            product_attributes.append({'name': k,
                                    'value': tmp_attr[k],
                                    'name_value': str(k) + ' ' + str(tmp_attr[k])})

    tmp_doc = {
        'product_uid': row['product_uid'],
        'product_title': row['product_title'],
        'product_description': row['product_description'],
        'product_attributes': product_attributes,
        'query_scores': query_scores
    }
    product_document_list.append(tmp_doc)

# %%
# Index the documents

for p in tqdm(product_document_list):
    es.index(index=index_name, document=p)

# %% [markdown]
# # Run Text Queries

# %%
def query_elasticsearch_hybrid(
    es_client,
    index_name,
    search_text=None,
    search_vector=None,
    num_results=10,
    boost_values=None,
):
    """Queries Elasticsearch with search and optional query_id filter.

    Args:
        es_client: An Elasticsearch client object.
        index_name: The name of the index to query.
        search_text: The text to search for.
        search_vector: The vector to search with.
        num_results: The maximum number of results to return (default 10).
        boost_values: A dictionary containing the boost values for title, description, and attributes.

    Returns:
        The search results from Elasticsearch.
    """

    # Default boost values
    boost_values = boost_values or {
        "title_boost": 1,
        "description_boost": 1,
        "attributes_boost": 1,
        "vector_boost": 1,
    }

    should_clauses = []

    # Text match clauses:
    if search_text is not None:
        text_match_clauses = [
            {
                "match": {
                    "product_title": {
                        "query": search_text,
                        "boost": boost_values["title_boost"],
                    }
                }
            },
            {
                "match": {
                    "product_description": {
                        "query": search_text,
                        "boost": boost_values["description_boost"],
                    }
                }
            },
            {
                "nested": {
                    "path": "product_attributes",
                    "query": {
                        "match": {
                            "product_attributes.name_value": {
                                "query": search_text,
                                "boost": boost_values["attributes_boost"],
                            }
                        }
                    },
                }
            },
        ]

        should_clauses.extend(text_match_clauses)
    
    # Vector match clauses:
    if search_vector is not None:
        vetor_match_clause = {
                        "knn": {
                            "field": "product_vector",
                            "query_vector": search_vector,
                            "num_candidates": 50,
                            "boost": boost_values["vector_boost"],
                        }
                    }
        should_clauses.append(vetor_match_clause)

    query_body = {
        "size": num_results,
        "query": {
            "bool": {
                "should": should_clauses
            }
        },
    }

    results = es_client.search(index=index_name, body=query_body)
    return results

# %% [markdown]
# ## Sample Query

# %%
# A sample query

search_text = df_queries['search_term'][0]

results = query_elasticsearch_hybrid(es, 'products', search_text=search_text)

hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append(h['query_scores'][0]['query_id'])
        relevances.append(h['query_scores'][0]['relevance'])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(3)
# Out:
#      _index                   _id     _score  \
# 0  products  GA0vEY8BkfDieeoVm0_n  39.548923
# 1  products  wA0yEY8BkfDieeoVyNZS  33.432453
# 2  products  Rg0yEY8BkfDieeoV_uDh  33.432453
#
#                                              _source  product_uid  \
# 0  {'product_uid': 198519, 'product_title': 'Vera...       198519
# 1  {'product_uid': 170398, 'product_title': 'Marq...       170398
# 2  {'product_uid': 174846, 'product_title': 'Marq...       174846
#
#                                        product_title  \
# 0  Veranda White Vinyl Traditional Left/Right Ang...
# 1  Marquee Railing Black Right Multi-Angle Bracke...
# 2  Marquee Railing Black Left Multi-Angle Bracket...
#
#                                  product_description  \
# 0  The Traditional Vinyl White Left/Right Angle B...
# 1  Designed with a beautiful hammered-metal look,...
# 2  Designed with a beautiful hammered-metal look,...
#
#                                    product_attribute  \
# 0  [{'name': 'Accessory type', 'value': 'Left/Rig...
# 1  [{'name': 'Accessory type', 'value': 'Bracket'...
# 2  [{'name': 'Accessory type', 'value': 'Bracket'...
#
#                                             query_id  relevance
# 0  45476ecfe43c98557ae68d2eec00a37d8f21c0fef3d913...        2.0
# 1                                               None        NaN
# 2                                               None        NaN

# %%
# Create ground truth dictionary

filename = "query_runs/qrel.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        qrel = json.load(file)
else:
    qrel = {}

    for query in tqdm(df_relevance['query_id'].unique()):

        query_docs = df_relevance[df_relevance['query_id']==query].sort_values('relevance', ascending=False).reset_index(drop=True)
        query_doc_dict = {}
        for index, row in query_docs.iterrows():
            query_doc_dict[str(row['product_uid'])] = int(round(row['relevance']))-1
        
        qrel[query] = query_doc_dict
    with open(filename, "w") as file:
        json.dump(qrel, file)

# %% [markdown]
# ## Run the text queries

# %%
# Create query result dictionaries from text queries

filename = "query_runs/text.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_u = json.load(file)
else:

    start_time = time.time()

    run_u = {}

    for index, row in tqdm(df_queries[df_queries['has_relevant_results']==1].iterrows(),
                        total=len(df_queries[df_queries['has_relevant_results']==1])):
        search_term = row['search_term']
        search_query_id = row['query_id']
        
        results = query_elasticsearch_hybrid(es, 'products', search_text=search_term)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run_u[search_query_id] = query_doc_dict

    end_time = time.time()

    with open(filename, "w") as file:
        json.dump(run_u, file)
# Out:
# 100%|██████████| 11795/11795 [01:47<00:00, 109.47it/s]

# %% [markdown]
# ## Evaluate results

# %%
# Place to store results and initialize an evaluator

ranking_results = []
measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

# %%
# Evaluate text queries

results_df = pd.DataFrame(evaluator.evaluate(run_u))
results_dict = {}
for measure in measures:
    results_dict['mean '+measure] = results_df.loc[measure].mean()
results_df = pd.DataFrame(results_dict, index=[0])

results_df['run_name'] = 'textsearch'
results_df['run_time'] = end_time - start_time
results_df['run_timestamp'] = current_timestamp

ranking_results.append(results_df)

# %%
# Put the results into a dataframe and save

pd.concat(ranking_results)
# Out:
#    mean ndcg_cut_10  mean map_cut_10  mean recip_rank    run_name    run_time  \
# 0          0.184085         0.120573         0.265219  textsearch  107.798031
#
#                run_timestamp
# 0 2024-04-24 15:28:41.859735

# %% [markdown]
# # Tune Text Boosts

# %%
boost_list = []

for t in [1,2,4]:
    for d in [1,2,4]:
        for a in [1,2,4]:
            boost_list.append({"title_boost": t,
                               "description_boost": d,
                               "attributes_boost": a})

# %%
# Run text queries with boosts

measures = {'map_cut_10', 'ndcg_cut_10', 'recip_rank'} 
evaluator = pytrec_eval.RelevanceEvaluator(qrel, measures)

for boosts in tqdm(boost_list):

    run = {}

    for index, row in tqdm(df_queries[df_queries['has_relevant_results']==1].iterrows(),
                        total=len(df_queries[df_queries['has_relevant_results']==1])):
        search_term = row['search_term']
        search_query_id = row['query_id']
        
        results = query_elasticsearch_hybrid(es, 'products', search_term, query_id_filter=None, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run[search_query_id] = query_doc_dict

    results_df = pd.DataFrame(evaluator.evaluate(run))
    results_dict = {}
    for measure in measures:
        results_dict['mean '+measure] = results_df.loc[measure].mean()
    results_df = pd.DataFrame(results_dict, index=[0])

    boosts['mean map_cut_10'] = results_df['mean map_cut_10'].values[0]
    boosts['mean ndcg_cut_10'] = results_df['mean ndcg_cut_10'].values[0]
    boosts['mean recip_rank'] = results_df['mean recip_rank'].values[0]

# %%
pd.DataFrame(boost_list).sort_values('mean ndcg_cut_10')

# %%
for t in [6, 8]:
    for d in [1,2,4]:
        for a in [1,2,4]:
            boost_list.append({"title_boost": t,
                               "description_boost": d,
                               "attributes_boost": a})

# %%
for boosts in tqdm(boost_list[27:]):

    run = {}

    for index, row in tqdm(df_queries[df_queries['has_relevant_results']==1].iterrows(),
                        total=len(df_queries[df_queries['has_relevant_results']==1])):
        search_term = row['search_term']
        search_query_id = row['query_id']
        
        results = query_elasticsearch_hybrid(es, 'products', search_term, query_id_filter=None, num_results=10, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run[search_query_id] = query_doc_dict

    results_df = pd.DataFrame(evaluator.evaluate(run))
    results_dict = {}
    for measure in measures:
        results_dict['mean '+measure] = results_df.loc[measure].mean()
    results_df = pd.DataFrame(results_dict, index=[0])

    boosts['mean map_cut_10'] = results_df['mean map_cut_10'].values[0]
    boosts['mean ndcg_cut_10'] = results_df['mean ndcg_cut_10'].values[0]
    boosts['mean recip_rank'] = results_df['mean recip_rank'].values[0]

# %%
pd.DataFrame(boost_list).sort_values('mean ndcg_cut_10')

# %% [markdown]
# ## Run the boosted text queries

# %%
boosts = {"title_boost": 8,
          "description_boost": 2,
          "attributes_boost": 1}

# %%
# Create query result dictionaries from text queries

filename = "query_runs/run_boosted.json"

if os.path.isfile(filename):
    with open(filename, "r") as file:
        run_b = json.load(file)
else:
    run_b = {}

    start_time = time.time()

    for index, row in tqdm(df_queries[df_queries['has_relevant_results']==1].iterrows(),
                        total=len(df_queries[df_queries['has_relevant_results']==1])):
        search_term = row['search_term']
        search_query_id = row['query_id']
        
        results = query_elasticsearch_hybrid(es, 'products', search_text=search_term, boost_values=boosts)
        hits = pd.DataFrame(results['hits']['hits'])

        query_doc_dict = {}
        for index, row in hits.iterrows():
            query_doc_dict[str(row['_source']['product_uid'])] = row['_score']
        
        run_b[search_query_id] = query_doc_dict

    end_time = time.time()

    with open(filename, "w") as file:
        json.dump(run_b, file)
# Out:
# 100%|██████████| 11795/11795 [01:49<00:00, 107.84it/s]

# %%
# Evaluate text queries boosted

results_df = pd.DataFrame(evaluator.evaluate(run_b))
results_dict = {}
for measure in measures:
    results_dict['mean '+measure] = results_df.loc[measure].mean()
results_df = pd.DataFrame(results_dict, index=[0])

results_df['run_name'] = 'textsearch_boosted'
results_df['run_time'] = end_time - start_time
results_df['run_timestamp'] = current_timestamp

ranking_results.append(results_df)

# %%
# Put the results into a dataframe and save

ranking_results = pd.concat(ranking_results)
ranking_results.to_csv('query_runs/query_results.csv', index=False)

ranking_results
# Out:
#    mean ndcg_cut_10  mean map_cut_10  mean recip_rank            run_name  \
# 0          0.184085         0.120573         0.265219          textsearch
# 0          0.236859         0.161795         0.320755  textsearch_boosted
#
#      run_time              run_timestamp
# 0  107.798031 2024-04-24 15:28:41.859735
# 0  109.380949 2024-04-24 15:28:41.859735

# %% [markdown]
# # Run the Sample Query again

# %%
sample_query_id = '2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd459c3b4cb7c3f3d85c2'

# A sample query

search_text = df_queries[df_queries['query_id']==sample_query_id]['search_term'].values[0]
print(search_text)

results = query_elasticsearch_hybrid(es, 'products', search_text=search_text)

hits = pd.DataFrame(results['hits']['hits'])
# Out:
# carpet grass 10 feet

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append(h['query_scores'][0]['query_id'])
        relevances.append(h['query_scores'][0]['relevance'])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(10)
# Out:
#      _index                   _id     _score  \
# 0  products  Mw40EY8BkfDieeoV0TIF  28.645502
# 1  products  aQ0yEY8BkfDieeoVdsj4  26.909157
# 2  products  vg41EY8BkfDieeoVGj5V  26.744383
# 3  products  IAwrEY8BkfDieeoVY6Ko  26.309332
# 4  products  CgwtEY8BkfDieeoVhPuY  26.309332
# 5  products  0Q0zEY8BkfDieeoVZfKP  26.309332
# 6  products  fg40EY8BkfDieeoVDRDd  26.309332
# 7  products  9Q41EY8BkfDieeoVdE3b  26.309332
# 8  products  bw0uEY8BkfDieeoVFROJ  26.301285
# 9  products  0wwtEY8BkfDieeoVHepn  25.716066
#
#                                              _source  product_uid  \
# 0  {'product_uid': 209354, 'product_title': 'Scot...       209354
# 1  {'product_uid': 163405, 'product_title': 'Robe...       163405
# 2  {'product_uid': 212565, 'product_title': 'IMAG...       212565
# 3  {'product_uid': 110504, 'product_title': 'GREE...       110504
# 4  {'product_uid': 151195, 'product_title': 'GREE...       151195
# 5  {'product_uid': 183338, 'product_title': 'GREE...       183338
# 6  {'product_uid': 196687, 'product_title': 'GREE...       196687
# 7  {'product_uid': 216460, 'product_title': 'GREE...       216460
# 8  {'product_uid': 164125, 'product_title': 'GREE...       164125
# 9  {'product_uid': 143219, 'product_title': 'GREE...       143219
#
#                                        product_title  \
# 0   Scotts 10 lb. Turf Builder EZ Bermuda Grass Seed
# 1  Roberts 2.125 in. Carpet Cutter Replacement Bl...
# 2  IMAGE 32 oz. Ready-to-Spray Herbicide for St. ...
# 3  GREENLINE Pink Blend Artificial Grass Syntheti...
# 4  GREENLINE Slate Grey Artificial Grass Syntheti...
# 5  GREENLINE Caribbean Blue Artificial Grass Synt...
# 6  GREENLINE Caribbean Blue Artificial Grass Synt...
# 7  GREENLINE Slate Grey Artificial Grass Syntheti...
# 8  GREENLINE Jade 50 7.5 ft. x 10 ft. Artificial ...
# 9  GREENLINE Jade 50 15 ft. x Your Length Artific...
#
#                                  product_description  \
# 0  The Scotts 10 lb. EZ Seed for Bermuda Grass La...
# 1  The Roberts 10-388-3 Replacement Trimmer blade...
# 2  IMAGE for St. Augustine grass and Centipede gr...
# 3  GREENLINE Pink - add a splash of color to your...
# 4  GREENLINE Grey - add a splash of color to your...
# 5  GREENLINE Blue - add a splash of color to your...
# 6  GREENLINE Blue - add a splash of color to your...
# 7  GREENLINE Grey - add a splash of color to your...
# 8  Jade is our best value artificial grass. All t...
# 9  Jade is our best value artificial grass. All t...
#
#                                    product_attribute  \
# 0  [{'name': 'Bullet01', 'value': 'Grows in tough...
# 1  [{'name': 'Blade Length (In.)', 'value': '2.12...
# 2  [{'name': 'Application Type', 'value': 'Hose E...
# 3  [{'name': 'Bullet01', 'value': 'Bright, vibran...
# 4  [{'name': 'Bullet01', 'value': 'Bright, vibran...
# 5  [{'name': 'Bullet01', 'value': 'Bright, vibran...
# 6  [{'name': 'Bullet01', 'value': 'Bright, vibran...
# 7  [{'name': 'Bullet01', 'value': 'Bright, vibran...
# 8  [{'name': 'Bullet01', 'value': 'Appearance and...
# 9  [{'name': 'Bullet01', 'value': 'Appearance and...
#
#                                             query_id  relevance
# 0                                               None        NaN
# 1                                               None        NaN
# 2                                               None        NaN
# 3  c29c67231f2c05d8d6d275547806be0dd48b92bc8c46b7...       2.00
# 4  9b0197111d7e430e28ba9b8035d52358a0c1833abade58...       3.00
# 5                                               None        NaN
# 6                                               None        NaN
# 7                                               None        NaN
# 8  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       2.33
# 9  a3efcb30d8cdb147b5b8622cfbfb56cead04dbbe2934a8...       2.33

# %%
# Rerun with boosts
results = query_elasticsearch_hybrid(es, 'products', search_text=search_text, boost_values=boosts)

hits = pd.DataFrame(results['hits']['hits'])

# %%
product_uids = []
product_titles = []
product_descriptions = []
product_attributes = []
query_id_list = []
relevances = []
for h in hits['_source']:
    product_uids.append(h['product_uid'])
    product_titles.append(h['product_title'])
    product_descriptions.append(h['product_description'])
    product_attributes.append(h['product_attributes'])
    
    if len(h['query_scores'])>0:
        query_id_list.append(h['query_scores'][0]['query_id'])
        relevances.append(h['query_scores'][0]['relevance'])
    else:
        query_id_list.append(None)
        relevances.append(None)

hits['product_uid'] = product_uids
hits['product_title'] = product_titles
hits['product_description'] = product_descriptions
hits['product_attribute'] = product_attributes
hits['query_id'] = query_id_list
hits['relevance'] = relevances

hits.head(10)
# Out:
#      _index                   _id      _score  \
# 0  products  bw0uEY8BkfDieeoVFROJ  118.972030
# 1  products  gQwqEY8BkfDieeoV_JSo  115.103874
# 2  products  JwwtEY8BkfDieeoVK-2A  115.103874
# 3  products  nAwrEY8BkfDieeoVD5dw  112.753320
# 4  products  7A0uEY8BkfDieeoVHhSK  112.525740
# 5  products  BQ0uEY8BkfDieeoVyDCA  112.269850
# 6  products  mw0uEY8BkfDieeoVyzB7  112.269850
# 7  products  iQ0yEY8BkfDieeoVpdDD  112.269850
# 8  products  DA0vEY8BkfDieeoVj00s  109.624620
# 9  products  zw0uEY8BkfDieeoVYh83  109.296684
#
#                                              _source  product_uid  \
# 0  {'product_uid': 164125, 'product_title': 'GREE...       164125
# 1  {'product_uid': 104985, 'product_title': 'GREE...       104985
# 2  {'product_uid': 144349, 'product_title': 'GREE...       144349
# 3  {'product_uid': 106230, 'product_title': 'GREE...       106230
# 4  {'product_uid': 164899, 'product_title': 'GREE...       164899
# 5  {'product_uid': 180045, 'product_title': 'GREE...       180045
# 6  {'product_uid': 180378, 'product_title': 'GREE...       180378
# 7  {'product_uid': 167422, 'product_title': 'GREE...       167422
# 8  {'product_uid': 197262, 'product_title': 'Turf...       197262
# 9  {'product_uid': 170738, 'product_title': 'Turf...       170738
#
#                                        product_title  \
# 0  GREENLINE Jade 50 7.5 ft. x 10 ft. Artificial ...
# 1  GREENLINE Classic 54 Fescue 5 ft. x 10 ft. Art...
# 2  GREENLINE Classic 54 Fescue 7.5 ft. x 10 ft. A...
# 3  GREENLINE Pet/Sport 60 5 ft. x 10 ft. Artifici...
# 4  GREENLINE Classic Pro 82 Spring 7.5 ft. x 10 f...
# 5  GREENLINE Classic Premium 65 Spring 5 ft. x 10...
# 6  GREENLINE Classic Premium 65 Fescue 7.5 ft. x ...
# 7  GREENLINE Classic Premium 65 Spring 7.5 ft. x ...
# 8  Turf Evolutions Deluxe Indoor Outdoor Landscap...
# 9  Turf Evolutions Luxurious Indoor Outdoor Lands...
#
#                                  product_description  \
# 0  Jade is our best value artificial grass. All t...
# 1  Classic 54 is the best value artificial grass ...
# 2  Classic 54 is the best value artificial grass ...
# 3  Sport/Pet 60 is the perfect solution for sport...
# 4  Classic Pro 82 is the top of the line in artif...
# 5  Classic Premium 65 is our most popular artific...
# 6  Classic Premium 65 is our most popular artific...
# 7  Classic Premium 65 is our most popular artific...
# 8  Turf Evolutions TruGrass Gold provides an envi...
# 9  Turf Evolutions TruGrass Tan provides an envir...
#
#                                    product_attribute  \
# 0  [{'name': 'Bullet01', 'value': 'Appearance and...
# 1  [{'name': 'Bullet01', 'value': 'Appearance and...
# 2  [{'name': 'Bullet01', 'value': 'Appearance and...
# 3  [{'name': 'Bullet01', 'value': 'Gentle on paws...
# 4  [{'name': 'Bullet01', 'value': 'Appearance and...
# 5  [{'name': 'Bullet01', 'value': 'Appearance and...
# 6  [{'name': 'Bullet01', 'value': 'Appearance and...
# 7  [{'name': 'Bullet01', 'value': 'Appearance and...
# 8  [{'name': 'Bullet01', 'value': 'All components...
# 9  [{'name': 'Bullet01', 'value': 'All components...
#
#                                             query_id  relevance
# 0  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       2.33
# 1  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       2.67
# 2  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       3.00
# 3  a3efcb30d8cdb147b5b8622cfbfb56cead04dbbe2934a8...       2.00
# 4  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       2.00
# 5  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       2.00
# 6  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       1.33
# 7                                               None        NaN
# 8  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       3.00
# 9  2702727dfc1076c3bd8affd42c05322c65ef8bb91e8dd4...       3.00
